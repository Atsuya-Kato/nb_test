# %%
import h5py

# %%
import numpy as np

# %%
from __future__ import print_function

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
W, H = (400,400)

# %%
f = h5py.File('/mnt/Omer/Project/07.DeepElectrodeMapping/kato/2019_0806_2/out.h5', 'r')

# %%
plt.imshow(f['2950']['v'].value.reshape((400,400)), cmap='hot')
