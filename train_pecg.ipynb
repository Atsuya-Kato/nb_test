# %%
import sys
sys.path.append('./ecg2mem/')
sys.path.append("/usr/lib/python2.7/dist-packages")
import dataProc
import preprocess.pseudoEcgCurve as pseudoEcgC
import preprocess.pseudoEcg as pseudoEcg
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D 


% matplotlib inline
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-1-ad6d231132be> in <module>()
#       2 sys.path.append('./ecg2mem/')
#       3 sys.path.append("/usr/lib/python2.7/dist-packages")
# ----> 4 import dataProc
#       5 import preprocess.pseudoEcgCurve as pseudoEcgC
#       6 import preprocess.pseudoEcg as pseudoEcg
#
# /notebooks/ecg2mem/dataProc.py in <module>()
#       1 # Do NOT import keras, tf or any other modules that require GPU in this file.
#       2
# ----> 3 import cv2
#       4 import numpy as np
#       5 import cv2 as cv
#
# ImportError: No module named cv2

# %%
elec_pos = np.zeros((25, 2), np.float32)
x_ = np.arange(93/10, 93-93/10, 93/5)
y_ = np.linspace(93-93/10, 93/10, 5)
np.arange(2, 12, 2)
for i in range(5):
    elec_pos[i*5:(i+1)*5, 0] = x_
    elec_pos[i*5:(i+1)*5, 1] = y_
print(elec_pos)
print(x_)
# Out:
# [[  9.    84.  ]
#  [ 27.    65.25]
#  [ 45.    46.5 ]
#  [ 63.    27.75]
#  [ 81.     9.  ]
#  [  9.    84.  ]
#  [ 27.    65.25]
#  [ 45.    46.5 ]
#  [ 63.    27.75]
#  [ 81.     9.  ]
#  [  9.    84.  ]
#  [ 27.    65.25]
#  [ 45.    46.5 ]
#  [ 63.    27.75]
#  [ 81.     9.  ]
#  [  9.    84.  ]
#  [ 27.    65.25]
#  [ 45.    46.5 ]
#  [ 63.    27.75]
#  [ 81.     9.  ]
#  [  9.    84.  ]
#  [ 27.    65.25]
#  [ 45.    46.5 ]
#  [ 63.    27.75]
#  [ 81.     9.  ]]
# [ 9 27 45 63 81]

# %%
z_dist_list = [2, 4, 6, 8, 10]
gnd_pos = np.array([[-93, 46, 10]], np.float32)

# %% [markdown]
# # 20190529_4

# %%
phie = dataProc.loadData('/mnt/Omer/Project/07.DeepElectrodeMapping/simulation/20190529_4/phie_')

# %%
elec = np.array([[150, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %% [markdown]
# # 20190529_5

# %%
phie = dataProc.loadData('/mnt/Omer/Project/07.DeepElectrodeMapping/simulation/20190529_5/phie_')

# %%
elec = np.array([[150, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %% [markdown]
# # 20190529_6

# %%
phie = dataProc.loadData('/mnt/Omer/Project/07.DeepElectrodeMapping/simulation/20190529_6/phie_')

# %%
elec = np.array([[150, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %% [markdown]
# # 20190530_2

# %%
phie = dataProc.loadData('/mnt/Omer/Project/07.DeepElectrodeMapping/simulation/20190530_2/phie_')

# %%
elec = np.array([[150, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %% [markdown]
# # 20190530_5

# %%
phie = dataProc.loadData('/mnt/Omer/Project/07.DeepElectrodeMapping/simulation/20190530_5/phie_')

# %%
elec = np.array([[150, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %% [markdown]
# # 20190601_1

# %%
phie = dataProc.loadData('/mnt/Omer/Project/07.DeepElectrodeMapping/simulation/20190601_1/phie_')

# %%
elec = np.array([[150, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %% [markdown]
# # 20190604_1

# %%
phie = dataProc.loadData('/mnt/Omer/Project/07.DeepElectrodeMapping/simulation/20190604_1/phie_')

# %%
elec = np.array([[150, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
phie = dataProc.loadData('/mnt/recordings/SimulationResults/2D/20170713-1/phie_')
# Out:
# IndexErrorTraceback (most recent call last)
# <ipython-input-32-b6cc11079e7e> in <module>()
# ----> 1 phie = dataProc.loadData('/mnt/recordings/SimulationResults/2D/20170713-1/phie_')
#
# /notebooks/ecg2mem/dataProc.pyc in loadData(srcDir, resize, dstSize, withChannel)
#     334         srcPathList = sorted(glob.glob(srcDir + '/*.npy'))
#     335     length = len(srcPathList)
# --> 336     sample = np.load(srcPathList[0])
#     337     src = np.ndarray(sample.shape, dtype=DATA_TYPE)
#     338     if not resize:
#
# IndexError: list index out of range
