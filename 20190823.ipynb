# %%
import sys
sys.path.append('./ecg2mem/')
sys.path.append("/usr/lib/python2.7/dist-packages")
import dataProc
import preprocess.pseudoEcg as pseudoEcg
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
# Out:
# ImportErrorTraceback (most recent call last)
# <ipython-input-1-404f80d3e169> in <module>()
#       2 sys.path.append('./ecg2mem/')
#       3 sys.path.append("/usr/lib/python2.7/dist-packages")
# ----> 4 import dataProc
#       5 import preprocess.pseudoEcg as pseudoEcg
#       6 import matplotlib.pyplot as plt
#
# /notebooks/ecg2mem/dataProc.py in <module>()
#       2
#       3 import numpy as np
# ----> 4 import cv2 as cv
#       5 import glob
#       6 import os
#
# ImportError: No module named cv2

# %% [markdown]
# # SW

# %%
phie = dataProc.loadData('/mnt/Omer/Project/07.DeepElectrodeMapping/simulation/20190524_2/phie_')

# %%
elec = np.array([[100, 100, 2]])
#pecg = pseudoEcg.calcPecgSequence(phie, elec)

# %%
elec
# Out:
# array([[100, 100,   2]])

# %%
elec.shape[1:3]
#elec.shape[1]
# Out:
# (3,)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg)
plt.show()

# %%
z_dist = np.linspace(0.2, 5, 20)
print(z_dist)
# Out:
# [ 0.2         0.45263158  0.70526316  0.95789474  1.21052632  1.46315789
#   1.71578947  1.96842105  2.22105263  2.47368421  2.72631579  2.97894737
#   3.23157895  3.48421053  3.73684211  3.98947368  4.24210526  4.49473684
#   4.74736842  5.        ]

# %%
plt.figure(figsize=(15,20))
for i, z in enumerate(z_dist):
    elec = np.array([[100, 100, z]])
    pecg = pseudoEcg.calcPecgSequence(phie, elec)
    plt.subplot(len(z_dist), 1, i+1)
    plt.plot(pecg)

# %%
elec = np.array([[100, 100, 9]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)
plt.show()

# %%
z_dist = np.linspace(2, 12, 12)
print(z_dist)
# Out:
# [  2.           2.90909091   3.81818182   4.72727273   5.63636364
#    6.54545455   7.45454545   8.36363636   9.27272727  10.18181818
#   11.09090909  12.        ]

# %%
plt.figure(figsize=(15,20))
for i, z in enumerate(z_dist):
    elec = np.array([[100, 100, z]])
    pecg = pseudoEcg.calcPecgSequence(phie, elec)
    plt.subplot(len(z_dist), 1, i+1)
    plt.text(0,z)
    plt.plot(pecg)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-55-da50970a6e2a> in <module>()
#       4     pecg = pseudoEcg.calcPecgSequence(phie, elec)
#       5     plt.subplot(len(z_dist), 1, i+1)
# ----> 6     plt.text(z)
#       7     plt.plot(pecg)
#
# TypeError: text() takes at least 3 arguments (1 given)

# %% [markdown]
# # pacing

# %%
phie = dataProc.loadData('/mnt/Omer/Project/07.DeepElectrodeMapping/simulation/20190522_3/phie_')

# %%
elec = np.array([[100, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
z_dist = np.linspace(0.2, 5, 20)
print(z_dist)
# Out:
# [ 0.2         0.45263158  0.70526316  0.95789474  1.21052632  1.46315789
#   1.71578947  1.96842105  2.22105263  2.47368421  2.72631579  2.97894737
#   3.23157895  3.48421053  3.73684211  3.98947368  4.24210526  4.49473684
#   4.74736842  5.        ]

# %%
plt.figure(figsize=(15,20))
for i, z in enumerate(z_dist):
    elec = np.array([[100, 100, z]])
    pecg = pseudoEcg.calcPecgSequence(phie, elec)
    plt.subplot(len(z_dist), 1, i+1)
    plt.plot(pecg)
