# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import ecg2mem.preprocess.pseudoEcg as pseudoEcg
import ecg2mem.preprocess.dataProc as dataProc

# %%
input_file = "./sim_results/20200130_2/out.h5"
with h5py.File(input_file,"r") as f:
    print('(1)----- 1st level -----')
    # ファイルオブジェクトをイテレートするとファイル直下のオブジェクト名を返す
    for k in f:
        print(k)
    print('(2)----- 2nd level -----')
    for k in f['0300']:
        print(k)
    print('(3)----- 3rd level -----')
    for k in f['0300/phie']:
        print(k)
# Out:
# (1)----- 1st level -----
# 0000
# 0001
# 0002
# 0003
# 0004
# 0005
# 0006
# 0007
# 0008
# 0009
# 0010
# 0011
# 0012
# 0013
# 0014
# 0015
# 0016
# 0017
# 0018
# 0019
# 0020
# 0021
# 0022
# 0023
# 0024
# 0025
# 0026
# 0027
# 0028
# 0029
# 0030
# 00300
# 0031
# 0032
# 0033
# 0034
# 0035
# 0036
# 0037
# 0038
# 0039
# 0040
# 0041
# 0042
# 0043
# 0044
# 0045
# 0046
# 0047
# 0048
# 0049
# 0050
# 0051
# 0052
# 0053
# 0054
# 0055
# 0056
# 0057
# 0058
# 0059
# 0060
# 0061
# 0062
# 0063
# 0064
# 0065
# 0066
# 0067
# 0068
# 0069
# 0070
# 0071
# 0072
# 0073
# 0074
# 0075
# 0076
# 0077
# 0078
# 0079
# 0080
# 0081
# 0082
# 0083
# 0084
# 0085
# 0086
# 0087
# 0088
# 0089
# 0090
# 0091
# 0092
# 0093
# 0094
# 0095
# 0096
# 0097
# 0098
# 0099
# 0100
# 0101
# 0102
# 0103
# 0104
# 0105
# 0106
# 0107
# 0108
# 0109
# 0110
# 0111
# 0112
# 0113
# 0114
# 0115
# 0116
# 0117
# 0118
# 0119
# 0120
# 0121
# 0122
# 0123
# 0124
# 0125
# 0126
# 0127
# 0128
# 0129
# 0130
# 0131
# 0132
# 0133
# 0134
# 0135
# 0136
# ...

# %%
x = np.ones((400,400))
x =np.where(x == 1, 1.41128048e-03 , 100)

# %%
input_file = "./sim_results/20200130_2/out.h5"
with h5py.File(input_file,"a") as f:
    f.create_dataset('0300/phie', data=x)

# %%
y = np.ones((400,400))

# %%
input_file = "./sim_results/20200130_2/out.h5"
with h5py.File(input_file,"a") as f:
    f.create_dataset('0300/fibro', data=y)

# %%
input_file = "./sim_results/20200130_2/out.h5"
with h5py.File(input_file,"r") as f:
    print('(1)----- 1st level -----')
    # ファイルオブジェクトをイテレートするとファイル直下のオブジェクト名を返す
    for k in f:
        print(k)
    print('(2)----- 2nd level -----')
    for k in f['0300']:
        print(k)
    print('(3)----- 3rd level -----')
    for k in f['0300/fibro']:
        print(k)
# Out:
# (1)----- 1st level -----
# 0000
# 0001
# 0002
# 0003
# 0004
# 0005
# 0006
# 0007
# 0008
# 0009
# 0010
# 0011
# 0012
# 0013
# 0014
# 0015
# 0016
# 0017
# 0018
# 0019
# 0020
# 0021
# 0022
# 0023
# 0024
# 0025
# 0026
# 0027
# 0028
# 0029
# 0030
# 00300
# 0031
# 0032
# 0033
# 0034
# 0035
# 0036
# 0037
# 0038
# 0039
# 0040
# 0041
# 0042
# 0043
# 0044
# 0045
# 0046
# 0047
# 0048
# 0049
# 0050
# 0051
# 0052
# 0053
# 0054
# 0055
# 0056
# 0057
# 0058
# 0059
# 0060
# 0061
# 0062
# 0063
# 0064
# 0065
# 0066
# 0067
# 0068
# 0069
# 0070
# 0071
# 0072
# 0073
# 0074
# 0075
# 0076
# 0077
# 0078
# 0079
# 0080
# 0081
# 0082
# 0083
# 0084
# 0085
# 0086
# 0087
# 0088
# 0089
# 0090
# 0091
# 0092
# 0093
# 0094
# 0095
# 0096
# 0097
# 0098
# 0099
# 0100
# 0101
# 0102
# 0103
# 0104
# 0105
# 0106
# 0107
# 0108
# 0109
# 0110
# 0111
# 0112
# 0113
# 0114
# 0115
# 0116
# 0117
# 0118
# 0119
# 0120
# 0121
# 0122
# 0123
# 0124
# 0125
# 0126
# 0127
# 0128
# 0129
# 0130
# 0131
# 0132
# 0133
# 0134
# 0135
# 0136
# ...

# %%
input_file = "/mnt/Share/Temp/kato/sim_results/20200309_6/out.h5"
with h5py.File(input_file,"r") as f:
    vmem1=np.ones(400)
    for i in range(400):
        v=f['{:0=4}'.format(i)]['vmem'].value
        v=v[200,200]
        vmem1[i]=v

# %%
input_file = "/mnt/Share/Temp/kato/sim_results/20200309_6/out.h5"
with h5py.File(input_file,"r") as f:
    vmem1=np.ones(400)
    for i in range(400):
        v=f['{:0=4}'.format(i)]['vmem'].value
        v=v[200,200]
        vmem1[i]=v

# %%
plt.plot(vmem1)
plt.show()

# %%
input_file = "/mnt/Share/Temp/kato/sim_results/20200309_1/out.h5"
with h5py.File(input_file,"r") as f:
    vmem=np.ones(400)
    for i in range(400):
        v=f['{:0=4}'.format(i)]['vmem'].value
        v=v[200,200]
        vmem[i]=v

# %%
plt.plot(vmem)
plt.show()

# %%
input_file = "/mnt/Share/Temp/kato/sim_results/20200309_4/out.h5"
with h5py.File(input_file,"r") as f:
    vmem1=np.ones(1000)
    for i in range(1000):
        v=f['{:0=4}'.format(i)]['vmem'].value
        v=v[200,300]
        vmem1[i]=v

# %%
# Out:
# (400, 400)

# %%
plt.plot(vmem1)
plt.xlim([0,400])
plt.show()

# %%
input_file = "/mnt/Share/Temp/kato/sim_results/20200309_4/out.h5"
with h5py.File(input_file,"r") as f:
    vmem2=np.ones(1000)
    for i in range(1000):
        v=f['{:0=4}'.format(i)]['vmem'].value
        v=v[200,200]
        vmem2[i]=v

# %%
plt.plot(vmem2)
plt.xlim([170,220])
plt.show()

# %%
input_file = "/mnt/Share/Temp/kato/sim_results/20200309_4/out.h5"
with h5py.File(input_file,"r") as f:
    vmem3=np.ones(1000)
    for i in range(1000):
        v=f['{:0=4}'.format(i)]['vmem'].value
        v=v[50,50]
        vmem3[i]=v

# %%
plt.plot(vmem3)
plt.xlim([120,170])
plt.show()

# %%
input_file = "/mnt/Share/Temp/kato/sim_results/20200309_4/out.h5"
with h5py.File(input_file,"r") as f:
    phie=np.zeros((1000,400,400))
    for i in range(1000):
        v=f['{:0=4}'.format(i)]['phie'].value
        phie[i]=v

# %%
phie=phie[:,:, :, np.newaxis]

# %%
phie.shape
# Out:
# (1000, 400, 400, 1)

# %%
elec = np.array([[200, 200, 8]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)

# %%
plt.plot(pecg)
plt.show()

# %%
elec = np.array([[200, 220, 8]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.plot(pecg)
plt.show()

# %%
elec = np.array([[200, 300, 8]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.plot(pecg)
plt.show()

# %%
elec = np.array([[50, 50, 8]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.plot(pecg)
plt.show()

# %%
elec = np.array([[100, 50, 8]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.plot(pecg)
plt.show()

# %%
elec = np.array([[200, 100, 8]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.plot(pecg)
plt.show()

# %%
a=np.ones((4,2))

# %%
a[0,1]
# Out:
# 1.0

# %%
vmem=np.ome
# Out:
# (1000,)

# %%
phie = dataProc.loadData('/mnt/Share/Project/07.DeepElectrodeMapping/simulation/20190511_1/phie_')

# %%
phie.shape
# Out:
# (501, 200, 200, 1)
