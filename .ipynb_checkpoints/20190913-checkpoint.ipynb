# %%
import numpy as np
import random
from matplotlib import pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
import math
import sys
sys.path.append('./ecg2mem/')
sys.path.append("/usr/lib/python2.7/dist-packages")
import dataProc
import preprocess.pseudoEcg_curve as pseudoEcgC
import preprocess.pseudoEcg as pseudoEcg
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 


% matplotlib inline

# %%
phie = dataProc.loadData('/mnt/Omer/Project/07.DeepElectrodeMapping/simulation/20190524_2/phie_')

# %%
elec = np.array([[130, 100, 10]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
vmem = dataProc.loadData('/mnt/Omer/Project/07.DeepElectrodeMapping/simulation/20190529_4/phie_')

# %%
elec = np.array([[100, 150, 8]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[100, 50, 4]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
phie = dataProc.loadData('/mnt/Omer/Project/07.DeepElectrodeMapping/simulation/20190530_2/phie_')

# %%
elec = np.array([[100, 100, 8]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %% [markdown]
# # 20190528_2

# %%
phie = dataProc.loadData('/mnt/Omer/Project/07.DeepElectrodeMapping/simulation/20190528_2/vmem_')

# %%
elec = np.array([[150, 50, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[150, 50, 6]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[150, 50, 10]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[25, 150, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[25, 150, 6]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[25, 150, 10]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[100, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[100, 100, 6]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[100, 100, 10]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %% [markdown]
# # 20190510_1

# %%
phie = dataProc.loadData('/mnt/Omer/Project/07.DeepElectrodeMapping/simulation/20190510_1/phie_')

# %%
elec = np.array([[100, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[100, 100, 4]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[100, 100, 6]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[100, 100, 8]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[100, 100, 10]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[75, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[75, 100, 4]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[75, 100, 6]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[50, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[50, 100, 4]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[50, 100, 6]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[30, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[10, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[20, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[100, 50, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[100, 50, 4]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[100, 50, 6]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[75, 50, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[75, 50, 4]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[75, 50, 6]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[125, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[150, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[125, 50, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[150, 50, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[100, 120, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[100, 120, 10]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[100, 140, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[100, 140, 10]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %% [markdown]
# # 20190522_9

# %%
phie = dataProc.loadData('/mnt/Omer/Project/07.DeepElectrodeMapping/simulation/20190522_9/phie_')

# %%
elec = np.array([[100, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[100, 100, 6]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[125, 150, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[125, 150, 6]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[75, 150, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[75, 150, 6]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[150, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[150, 100, 6]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[100, 50, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
elec = np.array([[100, 50, 6]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)
plt.figure(figsize=(15,2))
plt.plot(pecg)
