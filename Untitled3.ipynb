# %%
import numpy as np
import random
from matplotlib import pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
import math
import sys
sys.path.append('./ecg2mem/')
sys.path.append("/usr/lib/python2.7/dist-packages")
import dataProc
import preprocess.pseudoEcg_curve as pseudoEcgC
import preprocess.pseudoEcg as pseudoEcg
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D 


% matplotlib inline

# %%
phie = dataProc.loadData('/mnt/Omer/Project/07.DeepElectrodeMapping/simulation/20190510_1/phie_')

# %%
elec = np.array([[130, 100, 2]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
ref = np.array([[50, 50, 2]])
pecg2 = pseudoEcg.calcPecgSequence(phie, ref)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg2)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg-pecg2)

# %%
elec = np.array([[160, 10, 6]])
pecg = pseudoEcg.calcPecgSequence(phie, elec)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg)

# %%
ref = np.array([[150, 100, 6]])
pecg2 = pseudoEcg.calcPecgSequence(phie, ref)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg2)

# %%
plt.figure(figsize=(15,2))
plt.plot(pecg-pecg2)
