# %%
import os, sys, json, glob
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime as dt
from matplotlib import animation, rc
from IPython.display import HTML

from elecpy.simulator_bidomain import BidomainSimulator
from elecpy.util.cmap_bipolar import bipolar
from elecpy.util.loader import Loader
import h5py
# Out:
# pyculib:1: ImportWarning: Numba version too old; expecting 0.33.0

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 400, 'width': 400},
  'log': {'cnt': 200,
   'path': './sim_results/20200201_9'},
    'stimulation': {'extracellular': [
    {'amplitude': 80.0,
     'duration': 10.0,
     'interval': 300,
     'name': 'edge_L',
     'shape': [400, 400],
     'size': 5,
     'start': 0,
     'train': 10}]},
  'time': {u'end': 300, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
        img = step.next()
        if img is False: break
        out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------300.0/300mselecpy done

# %%
fig = plt.figure()
plt.axis('off')

ims = []
for img in out:
    im = plt.imshow(
        img.reshape(400,400),
        vmin = -100.0, vmax = 20.0,
        cmap=bipolar(neutral=0, lutsize=1024),
        interpolation='nearest')
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_html5_video())
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
T=2000

v=np.zeros(T)
for i in range(1,T-1):
    a  = h5file["{0:0>5}/v".format(i)].value 
    #ti = np.arange(0,100.,1)
    #ax_v.plot(ti,v,'o')
    v[i]=a

time=np.arange(0,T,1)
plt.plot(time,v)
plt.show()

# %%
sim_params= {
    'cell_type': 'courtmanche',
    'geometory': {
        'ds': 0.015, 'height': 400, 'width': 400
    },
    'log': {
        'cnt': 1000,
        'path': './sim_results/20200201_10'
    },
    'restart': {'count': 295,
    'source': './sim_results/20200201_9/'},
    'stimulation': {'membrane': [
         
            {
                'amplitude': 30.0,
                'duration': 5.0,
                'interval': 300,
                'name': 'edge_B',
                'shape': [400, 400],
                'size': 200,
                'start': 0,
                'train': 1
            }
        ]
    },
    'time': {
        u'end': 10,
        u'udt': 0.005
    }
}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------10.0/10mselecpy done

# %%
fig = plt.figure()
plt.axis('off')

ims = []
for img in out:
    im = plt.imshow(
        img.reshape(400,400),
        vmin = -100.0, vmax = 20.0,
        cmap=bipolar(neutral=0, lutsize=1024),
        interpolation='nearest')
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_html5_video())
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# # courtmanche bidomain 膜刺激

# %% [markdown]
# ### amp-50mV dur5.0 ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_1'},
    'stimulation': {'membrane': [
    {'amplitude': -50.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 20, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------20.0/20mselecpy done

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_2'},
    'stimulation': {'membrane': [
    {'amplitude': 50.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 20, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------20.0/20mselecpy done

# %%
fig = plt.figure()
plt.axis('off')

ims = []
for img in out:
    im = plt.imshow(
        img.reshape(200,200),
        vmin = -100.0, vmax = 20.0,
        cmap=bipolar(neutral=0, lutsize=1024),
        interpolation='nearest')
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_html5_video())
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### amp80mV dur5.0 ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_3'},
    'stimulation': {'membrane': [
    {'amplitude': 80.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 20, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------20.0/20mselecpy done

# %%
fig = plt.figure()
plt.axis('off')

ims = []
for img in out:
    im = plt.imshow(
        img.reshape(200,200),
        vmin = -100.0, vmax = 20.0,
        cmap=bipolar(neutral=0, lutsize=1024),
        interpolation='nearest')
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_html5_video())
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### amp-80mV dur5.0 ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_4'},
    'stimulation': {'membrane': [
    {'amplitude': -80.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------10.0/10mselecpy done

# %%
fig = plt.figure()
plt.axis('off')

ims = []
for img in out:
    im = plt.imshow(
        img.reshape(200,200),
        vmin = -100.0, vmax = 20.0,
        cmap=bipolar(neutral=0, lutsize=1024),
        interpolation='nearest')
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_html5_video())
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### amp100mV dur8.0 ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_5'},
    'stimulation': {'membrane': [
    {'amplitude': 100.0,
     'duration': 8.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 20, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------14.0/20mserror : invalid value nan @ 14.0 ms, index 14305
# elecpy done

# %% [markdown]
# ### amp-100mV dur8.0 ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_6'},
    'stimulation': {'membrane': [
    {'amplitude': -100.0,
     'duration': 8.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 20, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------14.0/20mserror : invalid value nan @ 14.0 ms, index 14305
# elecpy done

# %% [markdown]
# ### amp-100mV dur5.0 ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_6'},
    'stimulation': {'membrane': [
    {'amplitude': -100.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 20, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------20.0/20mselecpy done

# %%
fig = plt.figure()
plt.axis('off')

ims = []
for img in out:
    im = plt.imshow(
        img.reshape(200,200),
        vmin = -100.0, vmax = 20.0,
        cmap=bipolar(neutral=0, lutsize=1024),
        interpolation='nearest')
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_html5_video())
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### amp-120mV dur5.0 ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_7'},
    'stimulation': {'membrane': [
    {'amplitude': -120.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------10.0/10mselecpy done

# %%
fig = plt.figure()
plt.axis('off')

ims = []
for img in out:
    im = plt.imshow(
        img.reshape(200,200),
        vmin = -100.0, vmax = 20.0,
        cmap=bipolar(neutral=0, lutsize=1024),
        interpolation='nearest')
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_html5_video())
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### amp-150mV dur5.0 ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': -150.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------10.0/10mselecpy done

# %%
fig = plt.figure()
plt.axis('off')

ims = []
for img in out:
    im = plt.imshow(
        img.reshape(200,200),
        vmin = -100.0, vmax = 20.0,
        cmap=bipolar(neutral=0, lutsize=1024),
        interpolation='nearest')
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_html5_video())
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### amp-200mV dur5.0 ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': -200.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------10.0/10mselecpy done

# %%
fig = plt.figure()
plt.axis('off')

ims = []
for img in out:
    im = plt.imshow(
        img.reshape(200,200),
        vmin = -100.0, vmax = 20.0,
        cmap=bipolar(neutral=0, lutsize=1024),
        interpolation='nearest')
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_html5_video())
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### amp-250mV dur5.0 ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': -250.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------10.0/10mselecpy done

# %%
fig = plt.figure()
plt.axis('off')

ims = []
for img in out:
    im = plt.imshow(
        img.reshape(200,200),
        vmin = -100.0, vmax = 20.0,
        cmap=bipolar(neutral=0, lutsize=1024),
        interpolation='nearest')
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_html5_video())
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### amp-350mV dur5.0 ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': -350.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------10.0/10mselecpy done

# %%
fig = plt.figure()
plt.axis('off')

ims = []
for img in out:
    im = plt.imshow(
        img.reshape(200,200),
        vmin = -100.0, vmax = 20.0,
        cmap=bipolar(neutral=0, lutsize=1024),
        interpolation='nearest')
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_html5_video())
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### amp-750mV dur5.0 ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': -750.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------10.0/10mselecpy done

# %%
fig = plt.figure()
plt.axis('off')

ims = []
for img in out:
    im = plt.imshow(
        img.reshape(200,200),
        vmin = -100.0, vmax = 20.0,
        cmap=bipolar(neutral=0, lutsize=1024),
        interpolation='nearest')
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_html5_video())
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### amp-1000mV dur5.0 ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': -1000.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------10.0/10mselecpy done

# %%
fig = plt.figure()
plt.axis('off')

ims = []
for img in out:
    im = plt.imshow(
        img.reshape(200,200),
        vmin = -100.0, vmax = 20.0,
        cmap=bipolar(neutral=0, lutsize=1024),
        interpolation='nearest')
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_html5_video())
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### amp1000mV dur5.0 ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': 1000.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------10.0/10mselecpy done

# %%
fig = plt.figure()
plt.axis('off')

ims = []
for img in out:
    im = plt.imshow(
        img.reshape(200,200),
        vmin = -100.0, vmax = 20.0,
        cmap=bipolar(neutral=0, lutsize=1024),
        interpolation='nearest')
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_html5_video())
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### amp-1100mV dur6.0 ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': -1100.0,
     'duration': 6.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------6.0/10mserror : invalid value nan @ 6.0 ms, index 46
# elecpy done

# %% [markdown]
# ### amp-1200mV dur5.0 ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': -1200.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------5.0/10mserror : invalid value nan @ 5.0 ms, index 1099
# elecpy done

# %% [markdown]
# ### amp1100mV dur5.0ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': -1100.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------10.0/10mselecpy done

# %%
fig = plt.figure()
plt.axis('off')

ims = []
for img in out:
    im = plt.imshow(
        img.reshape(200,200),
        vmin = -100.0, vmax = 20.0,
        cmap=bipolar(neutral=0, lutsize=1024),
        interpolation='nearest')
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_html5_video())
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### amp-100mV dur6.0 ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': -100.0,
     'duration': 6.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------10.0/10mselecpy done

# %%
fig = plt.figure()
plt.axis('off')

ims = []
for img in out:
    im = plt.imshow(
        img.reshape(200,200),
        vmin = -100.0, vmax = 20.0,
        cmap=bipolar(neutral=0, lutsize=1024),
        interpolation='nearest')
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_html5_video())
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ### amp-100mV dur8.0 ms

# %%
 sim_params= {'cell_type': 'courtmanche',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': -100.0,
     'duration': 8.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------2.0/10ms

# %% [markdown]
# ## mahajan bidomain 膜刺激

# %%
sim_params= {'cell_type': 'mahajan',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': -30.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------1.0/10mserror : invalid value nan @ 1.0 ms, index 56
# elecpy done

# %%
sim_params= {'cell_type': 'mahajan',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': 30.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------1.0/10mserror : invalid value nan @ 1.0 ms, index 56
# elecpy done

# %%
sim_params= {'cell_type': 'mahajan',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 1000,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': 30.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.001}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------1.0/10mserror : invalid value nan @ 1.0 ms, index 0
# elecpy done

# %%
sim_params= {'cell_type': 'mahajan',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 1000,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': -30.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.001}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------1.0/10mserror : invalid value nan @ 1.0 ms, index 0
# elecpy done

# %%
sim_params= {'cell_type': 'mahajan',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 1000,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': -20.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.001}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------2.0/10mserror : invalid value nan @ 2.0 ms, index 0
# elecpy done

# %%
sim_params= {'cell_type': 'mahajan',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 1000,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': -10.0,
     'duration': 1.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.001}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------10.0/10mselecpy done

# %%
fig = plt.figure()
plt.axis('off')

ims = []
for img in out:
    im = plt.imshow(
        img.reshape(200,200),
        vmin = -100.0, vmax = 20.0,
        cmap=bipolar(neutral=0, lutsize=1024),
        interpolation='nearest')
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_html5_video())
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %% [markdown]
# ## luorudy bidomain 膜刺激

# %%
sim_params= {'cell_type': 'luorudy',
  'geometory': {'ds': 0.015, 'height': 200, 'width': 200},
  'log': {'cnt': 200,
   'path': './sim_results/bidomain/20200204_8'},
    'stimulation': {'membrane': [
    {'amplitude': -30.0,
     'duration': 5.0,
     'interval': 300,
     'name': 'point',
     'shape': [200, 200],
     'size': (100,100,5),
     'start': 0,
     'train': 10}]},
  'time': {u'end': 10, u'udt': 0.005}}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------1.0/10mserror : invalid value nan @ 1.0 ms, index 0
# elecpy done

# %%
sim_params= {
    'cell_type': 'courtmanche',
    'geometory': {
        'ds': 0.015, 'height': 400, 'width': 400
    },
    'log': {
        'cnt': 200,
        'path': './sim_results/bidomain/20200204_8/'
    },
    'restart': {'count': 300,
    'source': './sim_results/20200130_2'},
    'time': {
        u'end': 400,
        u'udt': 0.005
    }
}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data...
# KeyErrorTraceback (most recent call last)
# <ipython-input-71-9e23e8b42287> in <module>()
#       2 out=[]
#       3 while True:
# ----> 4     img = step.next()
#       5     if img is False: break
#       6     out.append(np.copy(img))
#
# /notebooks/elecpy/simulator_bidomain.pyc in step(self)
#     123                 group_id = '{0:0>4}'.format(cnt_restart)
#     124                 phie = f[group_id]['phie'].value.flatten()
# --> 125                 vmem = f[group_id]['vmem'].value.flatten()
#     126                 cells.load(f, group_id)
#     127             cnt_udt = cnt_restart * cnt_log
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/home/ilan/minonda/conda-bld/work/h5py/_objects.c:2696)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/home/ilan/minonda/conda-bld/work/h5py/_objects.c:2654)()
#
# /opt/conda/lib/python2.7/site-packages/h5py/_hl/group.pyc in __getitem__(self, name)
#     164                 raise ValueError("Invalid HDF5 object reference")
#     165         else:
# --> 166             oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     167
#     168         otype = h5i.get_type(oid)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/home/ilan/minonda/conda-bld/work/h5py/_objects.c:2696)()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper (/home/ilan/minonda/conda-bld/work/h5py/_objects.c:2654)()
#
# h5py/h5o.pyx in h5py.h5o.open (/home/ilan/minonda/conda-bld/work/h5py/h5o.c:3582)()
#
# KeyError: "Unable to open object (Object 'vmem' doesn't exist)"

# %% [markdown]
# # mono 2 bidomain

# %%
sim_params= {
    'cell_type': 'courtmanche',
    'geometory': {
        'ds': 0.015, 'height': 400, 'width': 400
    },
    'log': {
        'cnt': 200,
        'path': './sim_results/bidomain/20200204_9/'
    },
    'restart': {'count': 41,
    'source': './sim_results/hoge'},
    'time': {
        u'end': 100,
        u'udt': 0.005
    }
}

# %%
step = BidomainSimulator(sim_params).step()
out=[]
while True:
    img = step.next()
    if img is False: break
    out.append(np.copy(img))
del(step)
# Out:
# elecpy simulation start!
# Stimulation settings ...done
# Allocating data... ...done
# Initializing data... ...done
# Mask settings... ...done
# Building PDE system ... ...done
# Main loop start!
# ------------------100.0/100mselecpy done

# %%
fig = plt.figure()
plt.axis('off')

ims = []
for img in out:
    im = plt.imshow(
        img.reshape(400,400),
        vmin = -100.0, vmax = 20.0,
        cmap=bipolar(neutral=0, lutsize=1024),
        interpolation='nearest')
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims)
HTML(ani.to_html5_video())
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...
